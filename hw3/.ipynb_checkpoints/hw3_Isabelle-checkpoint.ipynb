# %%
import pandas as pd
import numpy as np
# from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import mean_squared_error, accuracy_score, f1_score, roc_auc_score
from scipy.stats import iqr
from sklearn.decomposition import PCA
from IPython.display import display, HTML
# import optuna.integration.lightgbm as lgb
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
import warnings
warnings. filterwarnings('ignore')

# %% [markdown]
# ### Part 1: Predict drug response on a per drug basis across the GDSC cell lines

# %% [markdown]
# Load files that contain gene expression information, fitted dose response results, and the information of the screen drugs.

# %%
# load and process dataset for gene expression levels on a cell-line basis
cell_line_rma = pd.read_csv('Cell_line_RMA_proc_basalExp_transposed.tsv', delimiter='\t')
cell_line_rma_dscrpt = cell_line_rma.iloc[0,:].copy()
cell_line_rma_data = cell_line_rma.iloc[1:,:].copy()
cell_line_rma_data['GENE_SYMBOLS'] = cell_line_rma_data['GENE_SYMBOLS'].str.split(".",expand=True)[1]
cell_line_rma_data_unique = cell_line_rma_data.drop_duplicates(subset=['GENE_SYMBOLS']).apply(pd.to_numeric)

# load dataset for cell-line and drug combination IC50 values
fitted_dose_response = pd.read_csv('v17_fitted_dose_response.tsv', delimiter='\t')

# load the file with drug names and information
GDSC_screened_compounds = pd.read_csv('GDSC_Screened_Compounds.tsv', delimiter='\t')

# %% [markdown]
# #### Details on model training
#
# The IC50 values were transformed into three categories (sensitive, intermediate, resistant) using the first and third quantiles of IC50 for each drug as threshold values.
#
# Stratified 5-fold cross-validation was employed for model development and evaluation, keeping class prevalence constant in each fold.
#
# PCA was used to reduce the feature dimension. I experimented with various numbers of components and determined that 50 would provide the highest efficiency without sacrificing model performance.
#
# Light Gradient Boosted Machine (LightGBM), a gradient boosting framework that uses tree based learning algorithms designed to have high efficiency, was used to make the predictions.
# A LightGBM regression model and a LightGBM classification model were trained on the same cross-validation split.
#
# Due to limitations on computational power, I'm not including the hyperparameter tuning step here, but it was performed separately and the parameters used here were selected from that process.
# Class weights were set to be inversely proportional to the class prevalence in order to address the class imbalance issue.
# Learning rate was reduced over time as a function of the current iteration number.
# Early stopping was implemented to avoid overfitting and reduce training time.
#
# RMSE was calculated for the regression model. Accuracy, F1-score, and AUC were calculated for the classification model. The F1-score calculated in each fold was the average F1-score of the three classes, weighted by the number of true instances for each label. The AUC calculated in each fold was the average AUC of all possible pairwise combinations of classes, weighted by the number of true instances for each label. For each drug, the metrics were first recorded for each of the 5 cross-validation folds, and finally I reported the metrics averaged across the 5 folds.

# %%
drug_ids = pd.unique(fitted_dose_response.DRUG_ID)
n_splits = 5
rmse = np.zeros((len(drug_ids),n_splits))
accuracy = np.zeros((len(drug_ids),n_splits))
f1 = np.zeros((len(drug_ids),n_splits))
auc = np.zeros((len(drug_ids),n_splits))

for i, drug in enumerate(drug_ids):
    fitted_dose_response_oneDrug = fitted_dose_response[fitted_dose_response['DRUG_ID']==drug]
    df = pd.merge(fitted_dose_response_oneDrug, cell_line_rma_data_unique, how="inner", left_on='COSMIC_ID', right_on='GENE_SYMBOLS')
    X = df.iloc[:,9:].copy()
    y = df['LN_IC50'].copy()
    
    # determine IC50 threshold values for SIR: 1st and 3rd quartile
    cutoff1, cutoff2 = y.quantile([0.25, 0.75])
    
    # categorical truth, encoded into numerical levels
    y_label = pd.cut(y, [-np.inf,cutoff1,cutoff2,np.inf], labels=['sensitive','intermediate','resistant'])
    le = LabelEncoder()
    le.fit(y_label)
    y_le = le.transform(y_label)

    # train and evaluate using stratified 5-fold cross-validation
    for j, (train, test) in enumerate(StratifiedKFold(n_splits=n_splits, random_state=7).split(X, y_label)):
        # feature selection/dimension reduction
        pca = PCA(n_components=50).fit(X.iloc[train])
        X_train = pca.transform(X.iloc[train])
        X_test = pca.transform(X.iloc[test])

        # regression model
        # splitting training fold into training and validation sets
        train_x, val_x, train_y, val_y = train_test_split(X_train, y[train], test_size=0.2)
        dtrain = lgb.Dataset(train_x, label=train_y)
        dval = lgb.Dataset(val_x, label=val_y)

        params = {"objective": "regression",
                  "metric": "l2",
                  "verbose": -1,
                  "boosting_type": "gbdt",
                  "class_weight": "balanced",
                  "num_leaves": 31,
                  "max_depth": 10,
                  "min_child_samples": 20,
                  "feature_fraction": 1}

        model_rg = lgb.train(params, dtrain, valid_sets=[dtrain, dval], 
                             verbose_eval=100, early_stopping_rounds=50,
                             learning_rates = lambda iter: 0.05 * (0.99 ** iter))
        
        y_pred_rg = model_rg.predict(X_test, num_iteration=model_rg.best_iteration)
        y_true = y[test]
        rmse[i,j] = mean_squared_error(y_true, y_pred_rg, squared=False)
        
        # classification model (SIR)
        train_x, val_x, train_y, val_y = train_test_split(X_train, y_le[train], test_size=0.2)
        dtrain = lgb.Dataset(train_x, label=train_y, params={'verbose': -1})
        dval = lgb.Dataset(val_x, label=val_y, params={'verbose': -1})

        params = {"objective": "multiclass",
                  "num_class": 3,
                  "metric": "multi_logloss",
                  "verbose": -1,
                  "boosting_type": "gbdt",
                  "class_weight": "balanced",
                  "num_leaves": 31,
                  "max_depth": 10,
                  "min_child_samples": 20,
                  "feature_fraction": 1}

        model_cl = lgb.train(params, dtrain, valid_sets=[dtrain, dval],
                             verbose_eval=100, early_stopping_rounds=50,
                             learning_rates = lambda iter: 0.05 * (0.99 ** iter))
        
        y_pred_cl = model_cl.predict(X_test, num_iteration=model_cl.best_iteration)
        y_pred_cl_cat = np.argmax(y_pred_cl, axis=1)
        y_true_cat = y_le[test]
        
        accuracy[i,j] = accuracy_score(y_true_cat, y_pred_cl_cat)
        # average F1-score of the three labels, weighted by the number of true instances for each label
        f1[i,j] = f1_score(y_true_cat, y_pred_cl_cat, average='weighted')
        # average AUC of all possible pairwise combinations of classes, weighted by the number of true instances for each label
        auc[i,j] = roc_auc_score(y_true_cat, y_pred_cl, multi_class='ovo', average='weighted')

# average evaluation metrics over the 5 folds, summarize in a dataframe, and sort by RMSE
scores1 = pd.DataFrame(np.c_[drug_ids, np.mean(rmse, axis=1), np.mean(accuracy, axis=1), np.mean(f1, axis=1), np.mean(auc, axis=1)],
                   columns=['Drug_ID','RMSE','Accuracy','F1-score','AUC']).sort_values('RMSE')
scores1['Drug_ID'] = scores1['Drug_ID'].astype('int64')
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.509879	valid_1's l2: 2.23119
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.509879	valid_1's l2: 2.23119
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.308098	valid_1's multi_logloss: 0.930301
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.308098	valid_1's multi_logloss: 0.930301
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.506726	valid_1's l2: 2.42743
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.506726	valid_1's l2: 2.42743
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.315298	valid_1's multi_logloss: 0.865518
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.315298	valid_1's multi_logloss: 0.865518
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.468619	valid_1's l2: 2.36799
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.468619	valid_1's l2: 2.36799
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's multi_logloss: 0.479517	valid_1's multi_logloss: 0.95443
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.507207	valid_1's l2: 2.36495
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.507207	valid_1's l2: 2.36495
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.320831	valid_1's multi_logloss: 0.944096
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.320831	valid_1's multi_logloss: 0.944096
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.498142	valid_1's l2: 2.86266
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.498142	valid_1's l2: 2.86266
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.318538	valid_1's multi_logloss: 0.892613
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.318538	valid_1's multi_logloss: 0.892613
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's l2: 0.298011	valid_1's l2: 0.485639
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.306067	valid_1's multi_logloss: 0.910236
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.306067	valid_1's multi_logloss: 0.910236
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.125954	valid_1's l2: 0.658661
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.125954	valid_1's l2: 0.658661
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.325765	valid_1's multi_logloss: 0.879593
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.325765	valid_1's multi_logloss: 0.879593
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's l2: 0.262196	valid_1's l2: 0.623743
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.607488	valid_1's multi_logloss: 0.960841
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's l2: 0.240319	valid_1's l2: 0.635001
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.588189	valid_1's multi_logloss: 1.0308
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.15202	valid_1's l2: 0.5164
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.15202	valid_1's l2: 0.5164
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.58748	valid_1's multi_logloss: 0.951321
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.890443	valid_1's l2: 0.509572
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01994	valid_1's multi_logloss: 1.04606
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.433004	valid_1's l2: 0.678657
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.828935	valid_1's multi_logloss: 1.04469
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 0.487455	valid_1's l2: 0.873615
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's multi_logloss: 0.512846	valid_1's multi_logloss: 1.00505
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's l2: 0.564255	valid_1's l2: 0.567298
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 0.804613	valid_1's multi_logloss: 1.04041
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 0.850681	valid_1's l2: 0.719093
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's multi_logloss: 0.564367	valid_1's multi_logloss: 1.01896
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's l2: 0.417556	valid_1's l2: 0.942938
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's multi_logloss: 0.499505	valid_1's multi_logloss: 0.991727
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	training's l2: 0.348989	valid_1's l2: 0.744425
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.325331	valid_1's multi_logloss: 0.977227
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.325331	valid_1's multi_logloss: 0.977227
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.490307	valid_1's l2: 0.809241
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.711121	valid_1's multi_logloss: 1.03872
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's l2: 0.432031	valid_1's l2: 0.811277
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.797225	valid_1's multi_logloss: 1.0636
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's l2: 0.66934	valid_1's l2: 0.797592
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.825261	valid_1's multi_logloss: 1.02385
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 1.52525	valid_1's l2: 2.78159
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.906289	valid_1's multi_logloss: 0.979752
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's l2: 1.17826	valid_1's l2: 2.69809
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.588733	valid_1's multi_logloss: 0.963152
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.615643	valid_1's l2: 2.97325
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.615643	valid_1's l2: 2.97325
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.328379	valid_1's multi_logloss: 0.98256
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.328379	valid_1's multi_logloss: 0.98256
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.619032	valid_1's l2: 2.04265
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.619032	valid_1's l2: 2.04265
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.843761	valid_1's multi_logloss: 0.980821
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.61943	valid_1's l2: 2.76439
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.61943	valid_1's l2: 2.76439
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.765524	valid_1's multi_logloss: 1.0037
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.447769	valid_1's l2: 1.49827
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.447769	valid_1's l2: 1.49827
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.310625	valid_1's multi_logloss: 0.871425
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.310625	valid_1's multi_logloss: 0.871425
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.389884	valid_1's l2: 1.43274
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.389884	valid_1's l2: 1.43274
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.301309	valid_1's multi_logloss: 0.84929
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.301309	valid_1's multi_logloss: 0.84929
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's l2: 0.897255	valid_1's l2: 1.66029
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's multi_logloss: 0.494766	valid_1's multi_logloss: 0.923077
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.42983	valid_1's l2: 1.3624
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.42983	valid_1's l2: 1.3624
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's multi_logloss: 0.482092	valid_1's multi_logloss: 0.893061
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.3691	valid_1's l2: 1.51357
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.3691	valid_1's l2: 1.51357
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.655119	valid_1's multi_logloss: 1.00462
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.129371	valid_1's l2: 0.580141
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.129371	valid_1's l2: 0.580141
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.557624	valid_1's multi_logloss: 0.984847
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.132522	valid_1's l2: 0.512093
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.132522	valid_1's l2: 0.512093
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.308609	valid_1's multi_logloss: 0.919408
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.308609	valid_1's multi_logloss: 0.919408
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.13173	valid_1's l2: 0.529159
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.13173	valid_1's l2: 0.529159
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.310379	valid_1's multi_logloss: 0.982403
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.310379	valid_1's multi_logloss: 0.982403
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.138997	valid_1's l2: 0.609386
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.138997	valid_1's l2: 0.609386
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's multi_logloss: 0.611208	valid_1's multi_logloss: 0.955044
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.135853	valid_1's l2: 0.45772
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.135853	valid_1's l2: 0.45772
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.299697	valid_1's multi_logloss: 1.05708
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.299697	valid_1's multi_logloss: 1.05708
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.295734	valid_1's l2: 1.12706
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.295734	valid_1's l2: 1.12706
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.768093	valid_1's multi_logloss: 1.0828
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's l2: 0.758745	valid_1's l2: 1.26545
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.612507	valid_1's multi_logloss: 0.951687
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 1.00752	valid_1's l2: 1.17812
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.611	valid_1's multi_logloss: 1.00094
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.395179	valid_1's l2: 1.54864
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.395179	valid_1's l2: 1.54864
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.558359	valid_1's multi_logloss: 0.961693
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's l2: 0.693843	valid_1's l2: 1.08898
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.325594	valid_1's multi_logloss: 0.960902
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.325594	valid_1's multi_logloss: 0.960902
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's l2: 0.582256	valid_1's l2: 1.41802
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.695696	valid_1's multi_logloss: 0.989716
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's l2: 0.527583	valid_1's l2: 1.34331
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 0.574593	valid_1's multi_logloss: 0.949108
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.281301	valid_1's l2: 1.31367
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.281301	valid_1's l2: 1.31367
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.629554	valid_1's multi_logloss: 0.988027
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.279351	valid_1's l2: 1.59147
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.279351	valid_1's l2: 1.59147
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.631248	valid_1's multi_logloss: 0.993176
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.814221	valid_1's l2: 1.37461
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.320862	valid_1's multi_logloss: 0.969654
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.320862	valid_1's multi_logloss: 0.969654
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.174579	valid_1's l2: 0.764699
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.174579	valid_1's l2: 0.764699
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.626923	valid_1's multi_logloss: 1.00883
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.174774	valid_1's l2: 0.69152
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.174774	valid_1's l2: 0.69152
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.342712	valid_1's multi_logloss: 0.95821
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.342712	valid_1's multi_logloss: 0.95821
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.153649	valid_1's l2: 0.895921
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.153649	valid_1's l2: 0.895921
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's multi_logloss: 0.570195	valid_1's multi_logloss: 0.959103
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.448204	valid_1's l2: 0.755224
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.67808	valid_1's multi_logloss: 1.00082
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's l2: 0.348091	valid_1's l2: 0.782313
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.989676	valid_1's multi_logloss: 0.987582
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.105604	valid_1's l2: 0.455617
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.105604	valid_1's l2: 0.455617
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.901523	valid_1's multi_logloss: 1.00856
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's l2: 0.196672	valid_1's l2: 0.407663
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.618275	valid_1's multi_logloss: 1.01475
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.107436	valid_1's l2: 0.667726
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.107436	valid_1's l2: 0.667726
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.318533	valid_1's multi_logloss: 0.998145
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.318533	valid_1's multi_logloss: 0.998145
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.105047	valid_1's l2: 0.558452
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.105047	valid_1's l2: 0.558452
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.718126	valid_1's multi_logloss: 0.959355
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 0.312051	valid_1's l2: 0.460706
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.63897	valid_1's multi_logloss: 0.974173
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 0.733845	valid_1's l2: 0.639246
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02614	valid_1's multi_logloss: 1.00515
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.545185	valid_1's l2: 0.745219
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01888	valid_1's multi_logloss: 1.03233
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.179364	valid_1's l2: 0.794677
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.179364	valid_1's l2: 0.794677
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.716995	valid_1's multi_logloss: 0.985773
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's l2: 0.478311	valid_1's l2: 0.728621
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.580311	valid_1's multi_logloss: 1.00652
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.729232	valid_1's l2: 0.841833
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.736101	valid_1's multi_logloss: 1.0032
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.326533	valid_1's l2: 0.649441
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's multi_logloss: 0.702339	valid_1's multi_logloss: 1.04029
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's l2: 0.463857	valid_1's l2: 0.555748
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.747373	valid_1's multi_logloss: 1.00751
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.115412	valid_1's l2: 0.614918
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.115412	valid_1's l2: 0.614918
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.648087	valid_1's multi_logloss: 1.01942
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's l2: 0.354349	valid_1's l2: 0.615324
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.00743	valid_1's multi_logloss: 1.08375
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's l2: 0.261461	valid_1's l2: 0.559673
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.735119	valid_1's multi_logloss: 1.0338
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.243228	valid_1's l2: 0.985882
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.243228	valid_1's l2: 0.985882
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.886635	valid_1's multi_logloss: 1.09471
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.230051	valid_1's l2: 1.14121
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.230051	valid_1's l2: 1.14121
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's multi_logloss: 0.678597	valid_1's multi_logloss: 1.05391
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.247318	valid_1's l2: 0.956388
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.247318	valid_1's l2: 0.956388
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02223	valid_1's multi_logloss: 1.01377
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 0.668606	valid_1's l2: 1.03738
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.592645	valid_1's multi_logloss: 0.962274
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.211507	valid_1's l2: 0.963388
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.211507	valid_1's l2: 0.963388
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.743196	valid_1's multi_logloss: 0.961552
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's l2: 0.539054	valid_1's l2: 1.44951
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.299459	valid_1's multi_logloss: 0.931463
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.299459	valid_1's multi_logloss: 0.931463
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.289125	valid_1's l2: 1.25466
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.289125	valid_1's l2: 1.25466
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.294997	valid_1's multi_logloss: 0.973583
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.294997	valid_1's multi_logloss: 0.973583
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.255283	valid_1's l2: 1.22811
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.255283	valid_1's l2: 1.22811
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.299559	valid_1's multi_logloss: 0.929214
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.299559	valid_1's multi_logloss: 0.929214
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.288142	valid_1's l2: 1.38214
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.288142	valid_1's l2: 1.38214
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.302329	valid_1's multi_logloss: 0.952052
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.302329	valid_1's multi_logloss: 0.952052
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.254773	valid_1's l2: 1.35085
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.254773	valid_1's l2: 1.35085
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.297284	valid_1's multi_logloss: 0.916898
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.297284	valid_1's multi_logloss: 0.916898
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.261103	valid_1's l2: 1.55543
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.261103	valid_1's l2: 1.55543
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.324218	valid_1's multi_logloss: 0.945765
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.324218	valid_1's multi_logloss: 0.945765
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's l2: 0.491973	valid_1's l2: 1.20501
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 0.581727	valid_1's multi_logloss: 1.02945
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.606384	valid_1's l2: 1.37089
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.302918	valid_1's multi_logloss: 0.919665
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.302918	valid_1's multi_logloss: 0.919665
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's l2: 0.629618	valid_1's l2: 1.04966
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.319272	valid_1's multi_logloss: 0.994383
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.319272	valid_1's multi_logloss: 0.994383
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.297204	valid_1's l2: 1.26967
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.297204	valid_1's l2: 1.26967
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 0.742129	valid_1's multi_logloss: 0.998691
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.292319	valid_1's l2: 1.37131
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.292319	valid_1's l2: 1.37131
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.619571	valid_1's multi_logloss: 1.00808
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.309387	valid_1's l2: 1.23311
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.309387	valid_1's l2: 1.23311
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.739868	valid_1's multi_logloss: 1.04848
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 1.00067	valid_1's l2: 1.61499
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.654602	valid_1's multi_logloss: 0.990211
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's l2: 0.961815	valid_1's l2: 1.31606
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.985499	valid_1's multi_logloss: 1.09139
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.308576	valid_1's l2: 1.0388
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.308576	valid_1's l2: 1.0388
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.637596	valid_1's multi_logloss: 1.01741
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.202104	valid_1's l2: 1.00281
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.202104	valid_1's l2: 1.00281
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.807506	valid_1's multi_logloss: 1.03991
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.208218	valid_1's l2: 0.901746
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.208218	valid_1's l2: 0.901746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 0.578635	valid_1's multi_logloss: 1.00776
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.196994	valid_1's l2: 1.00425
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.196994	valid_1's l2: 1.00425
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.650862	valid_1's multi_logloss: 0.992659
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.489303	valid_1's l2: 1.08519
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's multi_logloss: 0.689373	valid_1's multi_logloss: 1.02851
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's l2: 0.691697	valid_1's l2: 1.20288
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.902313	valid_1's multi_logloss: 1.0202
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 1.39507	valid_1's l2: 1.94058
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.699981	valid_1's multi_logloss: 1.0291
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 1.01752	valid_1's l2: 1.98893
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.895343	valid_1's multi_logloss: 1.00657
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.384773	valid_1's l2: 1.96752
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.384773	valid_1's l2: 1.96752
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.951311	valid_1's multi_logloss: 1.05184
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 1.33226	valid_1's l2: 1.75845
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0025	valid_1's multi_logloss: 1.10704
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.447422	valid_1's l2: 1.99219
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.447422	valid_1's l2: 1.99219
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.737711	valid_1's multi_logloss: 1.06984
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.400427	valid_1's l2: 2.66226
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.400427	valid_1's l2: 2.66226
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's multi_logloss: 0.644558	valid_1's multi_logloss: 0.971348
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's l2: 0.872846	valid_1's l2: 1.75527
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.663263	valid_1's multi_logloss: 0.986887
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.412139	valid_1's l2: 1.95494
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.412139	valid_1's l2: 1.95494
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.616353	valid_1's multi_logloss: 0.974132
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.434746	valid_1's l2: 1.95924
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.434746	valid_1's l2: 1.95924
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.324401	valid_1's multi_logloss: 0.872729
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.324401	valid_1's multi_logloss: 0.872729
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.452088	valid_1's l2: 1.94224
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.452088	valid_1's l2: 1.94224
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.311175	valid_1's multi_logloss: 0.973439
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.311175	valid_1's multi_logloss: 0.973439
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's l2: 0.654709	valid_1's l2: 1.46049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.93119	valid_1's multi_logloss: 1.02586
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.293049	valid_1's l2: 1.24388
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.293049	valid_1's l2: 1.24388
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.70106	valid_1's multi_logloss: 0.979842
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.276558	valid_1's l2: 1.09685
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.276558	valid_1's l2: 1.09685
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.689991	valid_1's multi_logloss: 0.972306
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.296115	valid_1's l2: 1.18687
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.296115	valid_1's l2: 1.18687
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's multi_logloss: 0.58163	valid_1's multi_logloss: 0.981372
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.283635	valid_1's l2: 1.61286
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.283635	valid_1's l2: 1.61286
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.330118	valid_1's multi_logloss: 0.960321
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.330118	valid_1's multi_logloss: 0.960321
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's l2: 1.3596	valid_1's l2: 2.18516
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's multi_logloss: 0.598193	valid_1's multi_logloss: 0.973973
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's l2: 1.3566	valid_1's l2: 2.23539
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.892588	valid_1's multi_logloss: 1.01326
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.466542	valid_1's l2: 1.87237
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.466542	valid_1's l2: 1.87237
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.981167	valid_1's multi_logloss: 1.08917
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's l2: 1.41306	valid_1's l2: 2.49911
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02266	valid_1's multi_logloss: 1.02225
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's l2: 1.05074	valid_1's l2: 2.54622
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.749526	valid_1's multi_logloss: 1.02296
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.245751	valid_1's l2: 1.03055
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.245751	valid_1's l2: 1.03055
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.624872	valid_1's multi_logloss: 1.0298
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.253251	valid_1's l2: 1.07466
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.253251	valid_1's l2: 1.07466
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.813496	valid_1's multi_logloss: 0.99733
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.218766	valid_1's l2: 1.10855
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.218766	valid_1's l2: 1.10855
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.609744	valid_1's multi_logloss: 0.994273
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 0.567015	valid_1's l2: 0.954247
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.692294	valid_1's multi_logloss: 0.977333
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.263392	valid_1's l2: 0.740152
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.263392	valid_1's l2: 0.740152
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's multi_logloss: 0.535225	valid_1's multi_logloss: 0.9557
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's l2: 1.31726	valid_1's l2: 1.97763
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.301027	valid_1's multi_logloss: 0.942258
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.301027	valid_1's multi_logloss: 0.942258
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.517435	valid_1's l2: 1.95111
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.517435	valid_1's l2: 1.95111
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.299093	valid_1's multi_logloss: 0.879611
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.299093	valid_1's multi_logloss: 0.879611
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.5153	valid_1's l2: 1.79615
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.5153	valid_1's l2: 1.79615
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.284415	valid_1's multi_logloss: 0.959353
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.284415	valid_1's multi_logloss: 0.959353
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.495174	valid_1's l2: 1.89046
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.495174	valid_1's l2: 1.89046
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.306486	valid_1's multi_logloss: 0.869106
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.306486	valid_1's multi_logloss: 0.869106
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.488483	valid_1's l2: 2.64494
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.488483	valid_1's l2: 2.64494
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's multi_logloss: 0.495868	valid_1's multi_logloss: 0.929933
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.23562	valid_1's l2: 1.04144
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.23562	valid_1's l2: 1.04144
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.319651	valid_1's multi_logloss: 0.941111
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.319651	valid_1's multi_logloss: 0.941111
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.297703	valid_1's l2: 0.572096
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.297703	valid_1's l2: 0.572096
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.695102	valid_1's multi_logloss: 0.987098
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's l2: 0.610063	valid_1's l2: 0.817577
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.314517	valid_1's multi_logloss: 0.960742
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.314517	valid_1's multi_logloss: 0.960742
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.307317	valid_1's l2: 1.17667
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.307317	valid_1's l2: 1.17667
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 0.781435	valid_1's multi_logloss: 0.984046
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.742783	valid_1's l2: 0.805594
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's multi_logloss: 0.532732	valid_1's multi_logloss: 0.962168
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.448496	valid_1's l2: 2.11801
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.448496	valid_1's l2: 2.11801
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.701852	valid_1's multi_logloss: 0.996766
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 1.48988	valid_1's l2: 1.30679
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.329408	valid_1's multi_logloss: 0.971627
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.329408	valid_1's multi_logloss: 0.971627
# Training until validation scores don't improve for 50 rounds
# ...
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's l2: 0.544848	valid_1's l2: 1.2973
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.338724	valid_1's multi_logloss: 1.07706
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.338724	valid_1's multi_logloss: 1.07706
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's l2: 0.841203	valid_1's l2: 1.59932
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.891296	valid_1's multi_logloss: 1.05441
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's l2: 0.778544	valid_1's l2: 1.33042
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.709758	valid_1's multi_logloss: 1.11407
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.320852	valid_1's l2: 1.4237
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.320852	valid_1's l2: 1.4237
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.00306	valid_1's multi_logloss: 1.0936
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 0.783937	valid_1's l2: 1.29758
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.785378	valid_1's multi_logloss: 1.02731
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's l2: 0.184183	valid_1's l2: 0.428451
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.694991	valid_1's multi_logloss: 1.0018
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.0761383	valid_1's l2: 0.439801
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.0761383	valid_1's l2: 0.439801
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.370665	valid_1's multi_logloss: 0.908333
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.370665	valid_1's multi_logloss: 0.908333
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's l2: 0.239229	valid_1's l2: 0.340909
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.703125	valid_1's multi_logloss: 0.968203
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.0943897	valid_1's l2: 0.376174
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.0943897	valid_1's l2: 0.376174
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's multi_logloss: 0.663351	valid_1's multi_logloss: 0.973394
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.0827647	valid_1's l2: 0.519818
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.0827647	valid_1's l2: 0.519818
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.74632	valid_1's multi_logloss: 0.951038
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's l2: 0.442884	valid_1's l2: 1.02769
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.338552	valid_1's multi_logloss: 0.923374
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.338552	valid_1's multi_logloss: 0.923374
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 0.670796	valid_1's l2: 0.899976
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's multi_logloss: 0.540704	valid_1's multi_logloss: 0.937378
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's l2: 1.04527	valid_1's l2: 1.12518
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 0.856595	valid_1's multi_logloss: 0.979591
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 0.635325	valid_1's l2: 1.36569
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.707252	valid_1's multi_logloss: 1.03502
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.297719	valid_1's l2: 0.799606
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.297719	valid_1's l2: 0.799606
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.645229	valid_1's multi_logloss: 1.0237
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's l2: 1.04363	valid_1's l2: 2.50443
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.834019	valid_1's multi_logloss: 1.03905
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.57026	valid_1's l2: 1.93093
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.57026	valid_1's l2: 1.93093
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.772464	valid_1's multi_logloss: 0.993777
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.6084	valid_1's l2: 1.85004
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.6084	valid_1's l2: 1.85004
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.777647	valid_1's multi_logloss: 1.04941
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.626165	valid_1's l2: 1.88798
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.626165	valid_1's l2: 1.88798
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's multi_logloss: 0.586594	valid_1's multi_logloss: 0.915293
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's l2: 1.96909	valid_1's l2: 2.90238
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.94885	valid_1's multi_logloss: 1.00383
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.243616	valid_1's l2: 1.01807
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.243616	valid_1's l2: 1.01807
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's multi_logloss: 0.594076	valid_1's multi_logloss: 1.05412
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.717032	valid_1's l2: 0.787127
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.767442	valid_1's multi_logloss: 0.987539
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.265926	valid_1's l2: 1.37521
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.265926	valid_1's l2: 1.37521
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 0.60152	valid_1's multi_logloss: 1.07364
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's l2: 0.772199	valid_1's l2: 1.17371
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.731599	valid_1's multi_logloss: 1.00306
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 0.578495	valid_1's l2: 1.28666
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.760074	valid_1's multi_logloss: 1.03893
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.417348	valid_1's l2: 0.926634
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 0.850374	valid_1's multi_logloss: 1.05715
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 0.478315	valid_1's l2: 0.954101
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.715508	valid_1's multi_logloss: 0.959792
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 0.796627	valid_1's l2: 0.813485
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.03104	valid_1's multi_logloss: 1.00657
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's l2: 0.832056	valid_1's l2: 0.973055
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.691154	valid_1's multi_logloss: 1.03156
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's l2: 0.818283	valid_1's l2: 0.7719
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.997604	valid_1's multi_logloss: 1.04591
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.261834	valid_1's l2: 0.794156
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.261834	valid_1's l2: 0.794156
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.366798	valid_1's multi_logloss: 0.901495
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.366798	valid_1's multi_logloss: 0.901495
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.27462	valid_1's l2: 0.829786
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.27462	valid_1's l2: 0.829786
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.850101	valid_1's multi_logloss: 1.05033
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 0.766133	valid_1's l2: 1.15735
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.635189	valid_1's multi_logloss: 0.97324
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's l2: 0.558485	valid_1's l2: 0.869116
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.744047	valid_1's multi_logloss: 0.963094
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's l2: 0.457507	valid_1's l2: 0.983834
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 0.669924	valid_1's multi_logloss: 1.05136
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's l2: 0.803633	valid_1's l2: 0.681884
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.344051	valid_1's multi_logloss: 0.969458
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.344051	valid_1's multi_logloss: 0.969458
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.387506	valid_1's l2: 0.770927
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.387506	valid_1's l2: 0.770927
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.941785	valid_1's multi_logloss: 1.02128
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.269359	valid_1's l2: 1.00176
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.269359	valid_1's l2: 1.00176
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.63191	valid_1's multi_logloss: 1.02522
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.929256	valid_1's l2: 1.15169
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 0.648855	valid_1's multi_logloss: 0.979543
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.402825	valid_1's l2: 1.2004
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.402825	valid_1's l2: 1.2004
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.352635	valid_1's multi_logloss: 0.934013
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.352635	valid_1's multi_logloss: 0.934013
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 1.81827	valid_1's l2: 1.95002
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.815607	valid_1's multi_logloss: 0.963013
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.462084	valid_1's l2: 1.4999
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.462084	valid_1's l2: 1.4999
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.357388	valid_1's multi_logloss: 0.921788
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.357388	valid_1's multi_logloss: 0.921788
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's l2: 1.80477	valid_1's l2: 1.60312
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.892088	valid_1's multi_logloss: 1.05271
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 1.1855	valid_1's l2: 2.06068
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.793752	valid_1's multi_logloss: 1.00267
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.476723	valid_1's l2: 2.92106
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.476723	valid_1's l2: 2.92106
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.894558	valid_1's multi_logloss: 1.01996

# %% [markdown]
# #### Results
#
# The top 10 and bottom 10 results (ranked by RMSE) are displayed below, including the drug ID and drug name along with all the performance metrics. Note that the performance ranked by RMSE is not necessarily the same as the ranking according to other metrics.

# %%
# merge scores with the file that contains drug names by drug ID
scores1 = pd.merge(scores1, GDSC_screened_compounds, left_on="Drug_ID", right_on="DRUG ID").iloc[:,np.r_[0,6,1:5]]
# show the top and bottom 10 results as ranked by RMSE
print('Top 10 results:')
display(scores1.head(10))
print('Bottom 10 results:')
display(scores1.tail(10))
# Out:
# Top 10 results:
#    Drug_ID     DRUG NAME      RMSE  Accuracy  F1-score       AUC
# 0     1262       UNC1215  0.467885  0.563934  0.544210  0.694333
# 1      266    Zibotentan  0.481658  0.553737  0.508785  0.687672
# 2      150  Bicalutamide  0.496250  0.512013  0.461134  0.626315
# 3     1264       SGC0946  0.536468  0.540503  0.481954  0.652593
# 4      341        EX-527  0.584964  0.510899  0.469021  0.659880
# 5       91    KIN001-135  0.603429  0.503549  0.441034  0.618908
# 6      205    BMS-708163  0.609634  0.487532  0.447266  0.627374
# 7     1502  Bicalutamide  0.619808  0.495487  0.394423  0.580183
# 8     1018     Veliparib  0.669887  0.510595  0.401222  0.602204
# 9      312     Tivozanib  0.676975  0.560253  0.531834  0.683065
# Bottom 10 results:
#      Drug_ID    DRUG NAME      RMSE  Accuracy  F1-score       AUC
# 255      299      OSI-027  2.051096  0.558375  0.522198  0.682304
# 256      344     THZ-2-49  2.077956  0.494553  0.443527  0.599821
# 257      302       PI-103  2.085635  0.563442  0.531582  0.678098
# 258       51    Dasatinib  2.106321  0.548038  0.527825  0.684081
# 259        3    Rapamycin  2.111996  0.487519  0.339373  0.540789
# 260      346  THZ-2-102-1  2.208040  0.564745  0.525582  0.687349
# 261      190    Bleomycin  2.273888  0.490751  0.373401  0.582560
# 262      268        YM155  2.308411  0.503929  0.394952  0.594042
# 263     1248        FK866  2.605698  0.598895  0.563300  0.719840
# 264      135  Gemcitabine  2.628593  0.468248  0.386788  0.570268

# %% [markdown]
# ### Part 2: Include additional assay types to improve model in part 1

# %% [markdown]
# Load files that contain the RACS results for cell lines.

# %%
# load and process dataset for RACS in cell lines
RACS_in_cell_lines = pd.read_csv('RACS_in_cell_lines.tsv', delimiter='\t')
# when multiple readings exist for a cell line, keep the first one
RACS_in_cell_lines_unique = RACS_in_cell_lines.drop_duplicates(subset=['COSMIC_ID'])
# simplify 'Region identifier' by removing anything in the parentheses - did not affect number of levels
RACS_in_cell_lines_unique['Region identifier short'] = RACS_in_cell_lines_unique['Region identifier'].str.split(" ", expand=True)[0]
# transform three potentially useful categorical variables to one-hot encoding
RACS_in_cell_lines_unique_onehot = pd.get_dummies(RACS_in_cell_lines_unique, columns=['Cancer Type','Alteration Type','Region identifier short'])

# %% [markdown]
# #### Details on model training
#
# I included 3 additional categorical features from the RACS assay results: cancer type, alteration type, and region identifier. These 3 features contributed to an additional 204 total featuers after one-hot encoding.
#
# The model training process followed that of part 1. Based on experimentation, the optimal number of components to keep during PCA was still 50.

# %%
rmse = np.zeros((len(drug_ids),n_splits))
accuracy = np.zeros((len(drug_ids),n_splits))
f1 = np.zeros((len(drug_ids),n_splits))
auc = np.zeros((len(drug_ids),n_splits))

for i, drug in enumerate(drug_ids):
    fitted_dose_response_oneDrug = fitted_dose_response[fitted_dose_response['DRUG_ID']==drug]
    df = pd.merge(fitted_dose_response_oneDrug, cell_line_rma_data_unique, how="inner", left_on='COSMIC_ID', right_on='GENE_SYMBOLS')
    df = pd.merge(df, RACS_in_cell_lines_unique_onehot.iloc[:,np.r_[1, 5:RACS_in_cell_lines_unique_onehot.shape[1]]], how="inner", on='COSMIC_ID')
    X = df.iloc[:,9:].copy()
    y = df['LN_IC50'].copy()
    
    # determine IC50 threshold values for SIR: 1st and 3rd quartile
    cutoff1, cutoff2 = y.quantile([0.25, 0.75])
    
    # categorical truth, encoded into numerical levels
    y_label = pd.cut(y, [-np.inf,cutoff1,cutoff2,np.inf], labels=['sensitive','intermediate','resistant'])
    le = LabelEncoder()
    le.fit(y_label)
    y_le = le.transform(y_label)

    # train and evaluate using stratified 5-fold cross-validation
    for j, (train, test) in enumerate(StratifiedKFold(n_splits=n_splits, random_state=7).split(X, y_label)):
        # feature selection/dimension reduction
        pca = PCA(n_components=50).fit(X.iloc[train])
        X_train = pca.transform(X.iloc[train])
        X_test = pca.transform(X.iloc[test])

        # regression model
        # splitting training fold into training and validation sets
        train_x, val_x, train_y, val_y = train_test_split(X_train, y[train], test_size=0.2)
        dtrain = lgb.Dataset(train_x, label=train_y)
        dval = lgb.Dataset(val_x, label=val_y)

        params = {"objective": "regression",
                  "metric": "l2",
                  "verbose": -1,
                  "boosting_type": "gbdt",
                  "class_weight": "balanced",
                  "num_leaves": 31,
                  "max_depth": 10,
                  "min_child_samples": 20,
                  "feature_fraction": 1}

        model_rg = lgb.train(params, dtrain, valid_sets=[dtrain, dval], 
                             verbose_eval=100, early_stopping_rounds=50,
                             learning_rates = lambda iter: 0.05 * (0.99 ** iter))
        
        y_pred_rg = model_rg.predict(X_test, num_iteration=model_rg.best_iteration)
        y_true = y[test]
        rmse[i,j] = mean_squared_error(y_true, y_pred_rg, squared=False)
        
        # classification model (SIR)
        train_x, val_x, train_y, val_y = train_test_split(X_train, y_le[train], test_size=0.2)
        dtrain = lgb.Dataset(train_x, label=train_y, params={'verbose': -1})
        dval = lgb.Dataset(val_x, label=val_y, params={'verbose': -1})

        params = {"objective": "multiclass",
                  "num_class": 3,
                  "metric": "multi_logloss",
                  "verbose": -1,
                  "boosting_type": "gbdt",
                  "class_weight": "balanced",
                  "num_leaves": 31,
                  "max_depth": 10,
                  "min_child_samples": 20,
                  "feature_fraction": 1}

        model_cl = lgb.train(params, dtrain, valid_sets=[dtrain, dval],
                             verbose_eval=100, early_stopping_rounds=50,
                             learning_rates = lambda iter: 0.05 * (0.99 ** iter))
        
        y_pred_cl = model_cl.predict(X_test, num_iteration=model_cl.best_iteration)
        y_pred_cl_cat = np.argmax(y_pred_cl, axis=1)
        y_true_cat = y_le[test]
        
        accuracy[i,j] = accuracy_score(y_true_cat, y_pred_cl_cat)
        # average F1-score of the three labels, weighted by the number of true instances for each label
        f1[i,j] = f1_score(y_true_cat, y_pred_cl_cat, average='weighted')
        # average AUC of all possible pairwise combinations of classes, weighted by the number of true instances for each label
        auc[i,j] = roc_auc_score(y_true_cat, y_pred_cl, multi_class='ovo', average='weighted')

# average evaluation metrics over the 5 folds, summarize in a dataframe, and sort by RMSE
scores2 = pd.DataFrame(np.c_[drug_ids, np.mean(rmse, axis=1), np.mean(accuracy, axis=1), np.mean(f1, axis=1), np.mean(auc, axis=1)],
                   columns=['Drug_ID','RMSE','Accuracy','F1-score','AUC']).sort_values('RMSE')
scores2['Drug_ID'] = scores2['Drug_ID'].astype('int64')
# Out:
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's l2: 1.30054	valid_1's l2: 1.93542
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.758503	valid_1's multi_logloss: 1.0005
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.623298	valid_1's l2: 2.90091
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.623298	valid_1's l2: 2.90091
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's multi_logloss: 0.540075	valid_1's multi_logloss: 0.9789
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's l2: 1.9729	valid_1's l2: 2.6024
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.55858	valid_1's multi_logloss: 0.975896
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 1.71114	valid_1's l2: 3.15381
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01521	valid_1's multi_logloss: 1.06826
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's l2: 1.17071	valid_1's l2: 3.42324
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 0.540176	valid_1's multi_logloss: 1.05162
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.667134	valid_1's l2: 0.469815
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.981356	valid_1's multi_logloss: 1.04189
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.426872	valid_1's l2: 0.431071
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.999835	valid_1's multi_logloss: 1.04972
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 0.679834	valid_1's l2: 0.476214
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.880522	valid_1's multi_logloss: 1.03102
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.374309	valid_1's l2: 0.697126
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's multi_logloss: 0.522806	valid_1's multi_logloss: 0.97507
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.19978	valid_1's l2: 0.395724
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.19978	valid_1's l2: 0.395724
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.927787	valid_1's multi_logloss: 1.07653
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's l2: 0.479924	valid_1's l2: 0.907133
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.961865	valid_1's multi_logloss: 1.04457
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's l2: 0.483335	valid_1's l2: 0.95892
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02031	valid_1's multi_logloss: 1.02221
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.207676	valid_1's l2: 0.700177
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.207676	valid_1's l2: 0.700177
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.981972	valid_1's multi_logloss: 1.06413
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 0.549907	valid_1's l2: 0.813086
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.831193	valid_1's multi_logloss: 1.00964
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 0.772514	valid_1's l2: 0.730539
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.928128	valid_1's multi_logloss: 0.956925
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 0.708724	valid_1's l2: 0.749982
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.360953	valid_1's multi_logloss: 0.971781
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.360953	valid_1's multi_logloss: 0.971781
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's l2: 0.633246	valid_1's l2: 0.622392
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.799709	valid_1's multi_logloss: 1.05755
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's l2: 0.366439	valid_1's l2: 0.755662
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.357793	valid_1's multi_logloss: 0.967676
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.357793	valid_1's multi_logloss: 0.967676
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 0.431888	valid_1's l2: 0.852428
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.890525	valid_1's multi_logloss: 1.13698
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.159928	valid_1's l2: 0.857026
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.159928	valid_1's l2: 0.857026
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.606673	valid_1's multi_logloss: 0.980943
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.638108	valid_1's l2: 2.59484
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.638108	valid_1's l2: 2.59484
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.935081	valid_1's multi_logloss: 1.03177
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's l2: 2.08775	valid_1's l2: 2.55746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.864426	valid_1's multi_logloss: 1.09267
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.71621	valid_1's l2: 1.69985
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.71621	valid_1's l2: 1.69985
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.360465	valid_1's multi_logloss: 0.94605
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.360465	valid_1's multi_logloss: 0.94605
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.611341	valid_1's l2: 2.82866
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.611341	valid_1's l2: 2.82866
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.961878	valid_1's multi_logloss: 0.978172
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 1.69181	valid_1's l2: 2.47735
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.657394	valid_1's multi_logloss: 1.03565
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.593386	valid_1's l2: 2.58167
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.593386	valid_1's l2: 2.58167
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's multi_logloss: 0.492979	valid_1's multi_logloss: 0.957127
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.544024	valid_1's l2: 2.45728
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.544024	valid_1's l2: 2.45728
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.304285	valid_1's multi_logloss: 0.952781
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.304285	valid_1's multi_logloss: 0.952781
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's l2: 1.31687	valid_1's l2: 2.08163
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's multi_logloss: 0.587975	valid_1's multi_logloss: 0.953519
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.564085	valid_1's l2: 2.31431
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.564085	valid_1's l2: 2.31431
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's multi_logloss: 0.46517	valid_1's multi_logloss: 0.890448
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.525544	valid_1's l2: 2.5359
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.525544	valid_1's l2: 2.5359
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.578769	valid_1's multi_logloss: 0.92997
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.15513	valid_1's l2: 0.560408
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.15513	valid_1's l2: 0.560408
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01858	valid_1's multi_logloss: 1.02344
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.636785	valid_1's l2: 0.602818
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 0.799115	valid_1's multi_logloss: 1.07988
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.388009	valid_1's l2: 0.716525
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.805722	valid_1's multi_logloss: 0.991935
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.133621	valid_1's l2: 0.613467
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.133621	valid_1's l2: 0.613467
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.854485	valid_1's multi_logloss: 0.954011
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.160451	valid_1's l2: 0.552244
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.160451	valid_1's l2: 0.552244
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's multi_logloss: 0.614346	valid_1's multi_logloss: 0.95989
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.431576	valid_1's l2: 1.6695
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.431576	valid_1's l2: 1.6695
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 0.666576	valid_1's multi_logloss: 1.03665
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.392885	valid_1's l2: 1.19027
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.392885	valid_1's l2: 1.19027
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 0.57948	valid_1's multi_logloss: 0.965753
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's l2: 1.67901	valid_1's l2: 0.91302
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.340447	valid_1's multi_logloss: 0.952627
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.340447	valid_1's multi_logloss: 0.952627
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.491387	valid_1's l2: 1.57714
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.491387	valid_1's l2: 1.57714
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.573981	valid_1's multi_logloss: 1.07864
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's l2: 1.50404	valid_1's l2: 2.02367
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.663508	valid_1's multi_logloss: 0.955223
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's l2: 0.596893	valid_1's l2: 1.27842
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.626694	valid_1's multi_logloss: 1.01015
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.283514	valid_1's l2: 1.24405
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.283514	valid_1's l2: 1.24405
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.8621	valid_1's multi_logloss: 1.00014
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's l2: 0.485781	valid_1's l2: 1.04158
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.868091	valid_1's multi_logloss: 0.99489
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.259567	valid_1's l2: 1.21099
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.259567	valid_1's l2: 1.21099
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 0.638967	valid_1's multi_logloss: 0.95038
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.305984	valid_1's l2: 0.895889
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.305984	valid_1's l2: 0.895889
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 0.872743	valid_1's multi_logloss: 1.01607
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.154854	valid_1's l2: 0.842
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.154854	valid_1's l2: 0.842
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.346714	valid_1's multi_logloss: 0.983204
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.346714	valid_1's multi_logloss: 0.983204
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.152707	valid_1's l2: 0.662348
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.152707	valid_1's l2: 0.662348
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.95846	valid_1's multi_logloss: 1.02154
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.399514	valid_1's l2: 0.617074
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.967493	valid_1's multi_logloss: 1.00293
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's l2: 0.35927	valid_1's l2: 0.558278
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.337738	valid_1's multi_logloss: 1.03401
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.337738	valid_1's multi_logloss: 1.03401
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 0.340889	valid_1's l2: 0.856156
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's multi_logloss: 0.670056	valid_1's multi_logloss: 0.974489
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.12296	valid_1's l2: 0.475785
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.12296	valid_1's l2: 0.475785
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.00603	valid_1's multi_logloss: 1.02689
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.53136	valid_1's l2: 0.460533
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.847299	valid_1's multi_logloss: 0.983167
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's l2: 0.223182	valid_1's l2: 0.419299
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.360891	valid_1's multi_logloss: 1.00665
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.360891	valid_1's multi_logloss: 1.00665
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.123734	valid_1's l2: 0.381861
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.123734	valid_1's l2: 0.381861
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0297	valid_1's multi_logloss: 1.00382
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's l2: 0.466907	valid_1's l2: 0.444088
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.98533	valid_1's multi_logloss: 1.08079
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.839339	valid_1's l2: 0.780668
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.982535	valid_1's multi_logloss: 1.04904
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's l2: 0.410653	valid_1's l2: 1.27827
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.772838	valid_1's multi_logloss: 1.01242
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.887774	valid_1's l2: 0.809208
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01584	valid_1's multi_logloss: 1.06221
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's l2: 0.781984	valid_1's l2: 0.813126
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.917214	valid_1's multi_logloss: 1.07966
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 0.458848	valid_1's l2: 0.729752
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 0.761752	valid_1's multi_logloss: 1.01706
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's l2: 0.4194	valid_1's l2: 0.664475
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02661	valid_1's multi_logloss: 0.995765
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's l2: 0.31161	valid_1's l2: 0.840741
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.907898	valid_1's multi_logloss: 1.09086
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's l2: 0.304542	valid_1's l2: 0.645368
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.949126	valid_1's multi_logloss: 1.04964
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's l2: 0.248939	valid_1's l2: 0.575
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.601416	valid_1's multi_logloss: 1.03633
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.133696	valid_1's l2: 0.571228
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.133696	valid_1's l2: 0.571228
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 0.828317	valid_1's multi_logloss: 1.09286
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's l2: 0.547795	valid_1's l2: 1.19482
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.992562	valid_1's multi_logloss: 0.99317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 1.05057	valid_1's l2: 1.27964
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.795842	valid_1's multi_logloss: 1.0281
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's l2: 0.506823	valid_1's l2: 1.22947
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's multi_logloss: 0.602209	valid_1's multi_logloss: 1.05516
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's l2: 0.724198	valid_1's l2: 1.02044
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02105	valid_1's multi_logloss: 1.05082
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's l2: 0.800293	valid_1's l2: 0.951387
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0293	valid_1's multi_logloss: 1.00606
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.333042	valid_1's l2: 0.933231
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.333042	valid_1's l2: 0.933231
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's multi_logloss: 0.529194	valid_1's multi_logloss: 0.998336
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 1.10414	valid_1's l2: 1.45145
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.876665	valid_1's multi_logloss: 1.00886
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.327953	valid_1's l2: 1.58694
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.327953	valid_1's l2: 1.58694
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.693179	valid_1's multi_logloss: 1.03201
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.320166	valid_1's l2: 1.27572
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.320166	valid_1's l2: 1.27572
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.320398	valid_1's multi_logloss: 0.94333
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.320398	valid_1's multi_logloss: 0.94333
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.323036	valid_1's l2: 1.25851
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.323036	valid_1's l2: 1.25851
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.327637	valid_1's multi_logloss: 0.921351
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.327637	valid_1's multi_logloss: 0.921351
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.20566	valid_1's l2: 0.963013
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.975491	valid_1's multi_logloss: 1.06749
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 0.700269	valid_1's l2: 1.05228
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0315	valid_1's multi_logloss: 0.972954
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's l2: 0.735732	valid_1's l2: 0.817368
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.988415	valid_1's multi_logloss: 1.04919
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's l2: 0.55304	valid_1's l2: 1.63514
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.596989	valid_1's multi_logloss: 1.02862
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 0.738369	valid_1's l2: 0.9403
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 0.775289	valid_1's multi_logloss: 1.06345
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.758765	valid_1's l2: 1.10977
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01322	valid_1's multi_logloss: 1.04989
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.26583	valid_1's l2: 1.52268
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.871493	valid_1's multi_logloss: 1.09128
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.30123	valid_1's l2: 1.33022
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.976167	valid_1's multi_logloss: 1.04329
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's l2: 0.547463	valid_1's l2: 1.01068
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0044	valid_1's multi_logloss: 1.09685
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.325946	valid_1's l2: 1.07393
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.325946	valid_1's l2: 1.07393
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0082	valid_1's multi_logloss: 1.07854
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 1.04642	valid_1's l2: 0.980413
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 0.832049	valid_1's multi_logloss: 0.978469
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.00332	valid_1's l2: 1.66049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.965485	valid_1's multi_logloss: 1.12162
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.272653	valid_1's l2: 1.45771
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.272653	valid_1's l2: 1.45771
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.899547	valid_1's multi_logloss: 1.01622
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.279009	valid_1's l2: 1.21802
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.279009	valid_1's l2: 1.21802
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.984813	valid_1's multi_logloss: 1.03426
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 0.73318	valid_1's l2: 1.23087
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.67161	valid_1's multi_logloss: 0.972073
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's l2: 1.44682	valid_1's l2: 1.95677
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.357645	valid_1's multi_logloss: 0.989976
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.357645	valid_1's multi_logloss: 0.989976
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's l2: 0.994468	valid_1's l2: 1.98687
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 0.980248	valid_1's multi_logloss: 1.12418
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.68023	valid_1's l2: 1.71714
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.963683	valid_1's multi_logloss: 1.10331
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l2: 1.57502	valid_1's l2: 1.78214
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01926	valid_1's multi_logloss: 1.04061
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l2: 1.61257	valid_1's l2: 2.06286
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01553	valid_1's multi_logloss: 1.05037
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 1.03231	valid_1's l2: 1.47122
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.748572	valid_1's multi_logloss: 0.968857
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's l2: 1.08966	valid_1's l2: 2.03179
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.918798	valid_1's multi_logloss: 1.0447
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's l2: 1.53733	valid_1's l2: 1.99417
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.826605	valid_1's multi_logloss: 1.04805
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.398715	valid_1's l2: 1.85091
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.398715	valid_1's l2: 1.85091
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 0.804707	valid_1's multi_logloss: 0.975561
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.438751	valid_1's l2: 1.92069
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.438751	valid_1's l2: 1.92069
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's multi_logloss: 0.612014	valid_1's multi_logloss: 1.05083
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's l2: 0.539003	valid_1's l2: 1.54325
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.726183	valid_1's multi_logloss: 1.0579
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.310397	valid_1's l2: 1.09481
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.310397	valid_1's l2: 1.09481
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.825495	valid_1's multi_logloss: 0.996301
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.863874	valid_1's l2: 1.43448
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.637315	valid_1's multi_logloss: 1.07067
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.324992	valid_1's l2: 1.23358
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.324992	valid_1's l2: 1.23358
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.351833	valid_1's multi_logloss: 0.901923
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.351833	valid_1's multi_logloss: 0.901923
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's l2: 0.802807	valid_1's l2: 1.18937
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.910519	valid_1's multi_logloss: 0.994757
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.417138	valid_1's l2: 1.99
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.417138	valid_1's l2: 1.99
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.720182	valid_1's multi_logloss: 1.03219
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 1.78119	valid_1's l2: 1.77697
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02844	valid_1's multi_logloss: 1.01126
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's l2: 0.9044	valid_1's l2: 1.28819
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.937986	valid_1's multi_logloss: 1.00876
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's l2: 1.55476	valid_1's l2: 1.65613
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.987943	valid_1's multi_logloss: 1.01077
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 1.03454	valid_1's l2: 1.8252
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.366052	valid_1's multi_logloss: 1.08342
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.366052	valid_1's multi_logloss: 1.08342
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.192004	valid_1's l2: 0.925204
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.192004	valid_1's l2: 0.925204
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.83781	valid_1's multi_logloss: 0.980176
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.620258	valid_1's l2: 0.989548
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.916645	valid_1's multi_logloss: 1.02674
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 0.537354	valid_1's l2: 0.884779
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.364155	valid_1's multi_logloss: 0.959075
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.364155	valid_1's multi_logloss: 0.959075
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.224532	valid_1's l2: 0.971472
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.224532	valid_1's l2: 0.971472
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 0.868032	valid_1's multi_logloss: 1.04553
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 0.514889	valid_1's l2: 0.856332
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's multi_logloss: 0.648972	valid_1's multi_logloss: 1.00287
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.621821	valid_1's l2: 2.49642
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.621821	valid_1's l2: 2.49642
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 0.649054	valid_1's multi_logloss: 0.931298
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.568017	valid_1's l2: 2.53879
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.568017	valid_1's l2: 2.53879
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.58415	valid_1's multi_logloss: 0.936753
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.54341	valid_1's l2: 2.2583
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.54341	valid_1's l2: 2.2583
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 0.794608	valid_1's multi_logloss: 0.975205
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.544898	valid_1's l2: 2.16303
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.544898	valid_1's l2: 2.16303
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 0.694814	valid_1's multi_logloss: 0.985683
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 2.00414	valid_1's l2: 2.66371
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.673306	valid_1's multi_logloss: 0.953127
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.327413	valid_1's l2: 1.73863
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.327413	valid_1's l2: 1.73863
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 0.697881	valid_1's multi_logloss: 1.05214
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's l2: 1.25957	valid_1's l2: 0.716939
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 0.874062	valid_1's multi_logloss: 1.00587
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.485968	valid_1's l2: 1.20364
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.485968	valid_1's l2: 1.20364
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 0.783253	valid_1's multi_logloss: 1.01704
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's l2: 0.646226	valid_1's l2: 1.87897
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's multi_logloss: 0.654976	valid_1's multi_logloss: 0.983047
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 0.987791	valid_1's l2: 1.03425
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.695538	valid_1's multi_logloss: 0.956121
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.59968	valid_1's l2: 1.96761
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.59968	valid_1's l2: 1.96761
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's multi_logloss: 0.516366	valid_1's multi_logloss: 0.99231
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's l2: 2.02548	valid_1's l2: 3.0106
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 0.997105	valid_1's multi_logloss: 1.13667
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 1.39036	valid_1's l2: 2.83279
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's multi_logloss: 0.533098	valid_1's multi_logloss: 1.04578
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.568157	valid_1's l2: 2.95503
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.568157	valid_1's l2: 2.95503
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.687426	valid_1's multi_logloss: 1.01941
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's l2: 1.04011	valid_1's l2: 2.7557
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.805609	valid_1's multi_logloss: 1.0601
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's l2: 0.693449	valid_1's l2: 1.22938
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01088	valid_1's multi_logloss: 1.0774
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.334235	valid_1's l2: 1.58694
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.334235	valid_1's l2: 1.58694
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 0.691364	valid_1's multi_logloss: 1.02064
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.895558	valid_1's l2: 1.45637
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.346701	valid_1's multi_logloss: 0.971794
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.346701	valid_1's multi_logloss: 0.971794
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's l2: 0.655575	valid_1's l2: 1.81493
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 0.754173	valid_1's multi_logloss: 1.04808
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's l2: 0.926514	valid_1's l2: 1.38021
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 0.623864	valid_1's multi_logloss: 1.03976
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.112605	valid_1's l2: 0.476822
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.112605	valid_1's l2: 0.476822
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.756767	valid_1's multi_logloss: 0.995265
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.133883	valid_1's l2: 0.390171
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.133883	valid_1's l2: 0.390171
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01313	valid_1's multi_logloss: 1.06997
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.127269	valid_1's l2: 0.505555
# Did not meet early stopping. Best iteration is:
# ...
# Early stopping, best iteration is:
# [12]	training's l2: 1.91888	valid_1's l2: 2.10504
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.930097	valid_1's multi_logloss: 1.01908
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l2: 1.35872	valid_1's l2: 1.48788
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.837095	valid_1's multi_logloss: 1.00238
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.416	valid_1's l2: 1.41347
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0227	valid_1's multi_logloss: 1.06987
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's l2: 1.00056	valid_1's l2: 1.68073
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.589555	valid_1's multi_logloss: 0.866033
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.589555	valid_1's multi_logloss: 0.866033
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's l2: 1.23974	valid_1's l2: 0.926744
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.923826	valid_1's multi_logloss: 1.04583
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l2: 1.34664	valid_1's l2: 1.75928
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.675788	valid_1's multi_logloss: 1.07319
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's l2: 0.317046	valid_1's l2: 0.407935
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.99489	valid_1's multi_logloss: 0.94174
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.156478	valid_1's l2: 0.38894
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.156478	valid_1's l2: 0.38894
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.04207	valid_1's multi_logloss: 0.984911
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.114575	valid_1's l2: 0.458743
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.114575	valid_1's l2: 0.458743
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 0.759821	valid_1's multi_logloss: 0.917037
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.183202	valid_1's l2: 0.283203
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.183202	valid_1's l2: 0.283203
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.04529	valid_1's multi_logloss: 0.984344
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.114078	valid_1's l2: 0.517103
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.114078	valid_1's l2: 0.517103
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.04023	valid_1's multi_logloss: 0.955868
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's l2: 1.0885	valid_1's l2: 1.44487
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's multi_logloss: 0.694266	valid_1's multi_logloss: 1.00746
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's l2: 1.25	valid_1's l2: 1.04807
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 0.798279	valid_1's multi_logloss: 1.19483
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.683589	valid_1's l2: 2.45531
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.683589	valid_1's l2: 2.45531
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.502831	valid_1's multi_logloss: 1.04968
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.502831	valid_1's multi_logloss: 1.04968
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.807835	valid_1's l2: 1.35786
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.807835	valid_1's l2: 1.35786
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 0.753752	valid_1's multi_logloss: 0.921139
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's l2: 1.46581	valid_1's l2: 1.11696
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.05341	valid_1's multi_logloss: 0.971086
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's l2: 2.56199	valid_1's l2: 3.30971
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 0.788915	valid_1's multi_logloss: 1.03017
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 3.52818	valid_1's l2: 3.58248
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.546496	valid_1's multi_logloss: 0.951597
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.546496	valid_1's multi_logloss: 0.951597
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 1.41744	valid_1's l2: 2.66887
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 1.41744	valid_1's l2: 2.66887
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 0.999744	valid_1's multi_logloss: 1.18549
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 1.53422	valid_1's l2: 2.00666
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 1.53422	valid_1's l2: 2.00666
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 0.888129	valid_1's multi_logloss: 0.919256
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 3.3514	valid_1's l2: 2.63154
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.864141	valid_1's multi_logloss: 1.04419
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 1.11186	valid_1's l2: 1.3251
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.659284	valid_1's multi_logloss: 1.02087
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 1.06417	valid_1's l2: 1.08841
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 0.95015	valid_1's multi_logloss: 1.0197
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.528562	valid_1's l2: 1.81815
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.528562	valid_1's l2: 1.81815
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.542785	valid_1's multi_logloss: 0.906049
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.542785	valid_1's multi_logloss: 0.906049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.52557	valid_1's l2: 1.24766
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 0.894104	valid_1's multi_logloss: 1.01758
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's l2: 0.676221	valid_1's l2: 1.62796
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 0.960231	valid_1's multi_logloss: 1.04835
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.771664	valid_1's l2: 1.543
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.03167	valid_1's multi_logloss: 1.01999
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.933948	valid_1's l2: 0.797879
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0227	valid_1's multi_logloss: 1.06519
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 0.691051	valid_1's l2: 0.926434
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.537332	valid_1's multi_logloss: 0.907422
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.537332	valid_1's multi_logloss: 0.907422
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's l2: 0.861244	valid_1's l2: 0.902831
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.06016	valid_1's multi_logloss: 0.982445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 1.03924	valid_1's l2: 1.0427
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 0.93003	valid_1's multi_logloss: 1.1756
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.635999	valid_1's l2: 0.822402
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 0.918176	valid_1's multi_logloss: 1.11158
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's l2: 0.776078	valid_1's l2: 1.21194
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.01714	valid_1's multi_logloss: 1.06375
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's l2: 0.872299	valid_1's l2: 0.91911
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.02544	valid_1's multi_logloss: 1.06405
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.413564	valid_1's l2: 0.797689
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.413564	valid_1's l2: 0.797689
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.973888	valid_1's multi_logloss: 1.09155
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's l2: 0.858419	valid_1's l2: 0.913803
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's multi_logloss: 0.714636	valid_1's multi_logloss: 1.05878
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's l2: 1.87906	valid_1's l2: 0.814574
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.00325	valid_1's multi_logloss: 1.0133
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 1.11837	valid_1's l2: 3.68812
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 0.970439	valid_1's multi_logloss: 1.05424
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's l2: 1.8249	valid_1's l2: 1.98421
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.811532	valid_1's multi_logloss: 1.14269
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.697635	valid_1's l2: 1.63582
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.697635	valid_1's l2: 1.63582
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 0.981337	valid_1's multi_logloss: 1.08461
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 1.04971	valid_1's l2: 0.921498
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 1.04971	valid_1's l2: 0.921498
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.0059	valid_1's multi_logloss: 1.14052
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's l2: 1.82861	valid_1's l2: 0.726068
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 0.83031	valid_1's multi_logloss: 0.959305
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 1.00451	valid_1's l2: 0.758186
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 1.00451	valid_1's l2: 0.758186
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.447783	valid_1's multi_logloss: 0.994995
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.447783	valid_1's multi_logloss: 0.994995
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's l2: 2.05	valid_1's l2: 1.39262
# Training until validation scores don't improve for 50 rounds
# [100]	training's multi_logloss: 0.514657	valid_1's multi_logloss: 0.979837
# Did not meet early stopping. Best iteration is:
# [100]	training's multi_logloss: 0.514657	valid_1's multi_logloss: 0.979837
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's l2: 1.58	valid_1's l2: 2.37786
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 0.684788	valid_1's multi_logloss: 0.838098
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 1.37286	valid_1's l2: 1.77339
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 1.37286	valid_1's l2: 1.77339
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.06299	valid_1's multi_logloss: 0.967714

# %% [markdown]
# #### Results and interpretation
#
# From the top 10 and bottom 10 results displayed, the results seem comparable to those in part 1.
#
# Although additional features were included to enrich available information for each cell line, the number of samples was reduced becuase the RACS assay results were not available for all cell lines. The performance may be furhter improved if more additional features are included and are available for most samples.

# %%
# merge scores with the file that contains drug names by drug ID
scores2 = pd.merge(scores2, GDSC_screened_compounds, left_on="Drug_ID", right_on="DRUG ID").iloc[:,np.r_[0,6,1:5]]
# show the top and bottom 10 results as ranked by RMSE
print('Top 10 results:')
display(scores2.head(10))
print('Bottom 10 results:')
display(scores2.tail(10))
# Out:
# Top 10 results:
#    Drug_ID     DRUG NAME      RMSE  Accuracy  F1-score       AUC
# 0     1262       UNC1215  0.472518  0.508163  0.416980  0.612979
# 1      266    Zibotentan  0.488698  0.470889  0.351787  0.538805
# 2      150  Bicalutamide  0.513033  0.501099  0.378952  0.545406
# 3     1264       SGC0946  0.550619  0.482558  0.343213  0.538195
# 4      312     Tivozanib  0.558262  0.508990  0.385626  0.562801
# 5       91    KIN001-135  0.576615  0.500000  0.355595  0.488576
# 6      205    BMS-708163  0.579681  0.494909  0.373588  0.535001
# 7      341        EX-527  0.590254  0.490909  0.347217  0.595839
# 8     1502  Bicalutamide  0.615387  0.481881  0.345217  0.506813
# 9     1375  Temozolomide  0.639171  0.513318  0.424858  0.611261
# Bottom 10 results:
#      Drug_ID    DRUG NAME      RMSE  Accuracy  F1-score       AUC
# 255      302       PI-103  2.124116  0.507071  0.369398  0.570876
# 256      299      OSI-027  2.126953  0.481818  0.345569  0.533079
# 257      344     THZ-2-49  2.140791  0.498990  0.353219  0.545002
# 258       56     WH-4-023  2.251761  0.484308  0.330523  0.536695
# 259       51    Dasatinib  2.287476  0.515385  0.377057  0.584219
# 260      190    Bleomycin  2.319254  0.496703  0.338232  0.494091
# 261      346  THZ-2-102-1  2.334517  0.503051  0.367316  0.560970
# 262      268        YM155  2.380884  0.494737  0.356004  0.522835
# 263     1248        FK866  2.509282  0.508333  0.418777  0.601301
# 264      135  Gemcitabine  2.776634  0.497802  0.361919  0.555571

# %% [markdown]
# ### Part 3: Rank drugs for given cell line

# %% [markdown]
# Because there were $265 \times 5 = 1325$ different by-drug regression models from the previous questions, I chose not to save them. In this part I retrained them in the same way to make predictions in this question. The same 5-fold cross-validation scheme was used as before, training the model on 80% of the data and testing on the rest 20% in each iteration. This time, rather than calculating evaluation metrics on the test sets, all predictions were saved to perform ranking in the end when we have scores for all drugs and all cell lines.

# %%
# dataframes for IC_50 results from model prediction and experiments
scores = pd.DataFrame(columns = drug_ids, index = cell_line_rma_data_unique.GENE_SYMBOLS) 
exprmt = pd.DataFrame(columns = drug_ids, index = cell_line_rma_data_unique.GENE_SYMBOLS) 

for i, drug in enumerate(drug_ids):
    fitted_dose_response_oneDrug = fitted_dose_response[fitted_dose_response['DRUG_ID']==drug]
    df = pd.merge(fitted_dose_response_oneDrug, cell_line_rma_data_unique, how="inner", left_on='COSMIC_ID', right_on='GENE_SYMBOLS')
    X = df.iloc[:,9:].copy()
    y = df['LN_IC50'].copy()
    ids = df['COSMIC_ID'].copy()
    
    # add experimental results for this drug to a dataframe
    exprmt.loc[df.GENE_SYMBOLS, drug] = y.values
    
    # determine IC50 threshold values for SIR: 1st and 3rd quartile
    cutoff1, cutoff2 = y.quantile([0.25, 0.75])
    
    # categorical truth, encoded into numerical levels
    y_label = pd.cut(y, [-np.inf,cutoff1,cutoff2,np.inf], labels=['sensitive','intermediate','resistant'])

    # train and predict using stratified 5-fold cross-validation
    for j, (train, test) in enumerate(StratifiedKFold(n_splits=n_splits, random_state=7).split(X, y_label)):
        # feature selection/dimension reduction
        pca = PCA(n_components=50).fit(X.iloc[train])
        X_train = pca.transform(X.iloc[train])
        X_test = pca.transform(X.iloc[test])

        # regression model
        # splitting training fold into training and validation sets
        train_x, val_x, train_y, val_y = train_test_split(X_train, y[train], test_size=0.2)
        dtrain = lgb.Dataset(train_x, label=train_y)
        dval = lgb.Dataset(val_x, label=val_y)
        
        params = {"objective": "regression",
                  "metric": "l2",
                  "verbose": -1,
                  "boosting_type": "gbdt",
                  "class_weight": "balanced",
                  "num_leaves": 31,
                  "max_depth": 10,
                  "min_child_samples": 20,
                  "feature_fraction": 1}

        model_rg = lgb.train(params, dtrain, valid_sets=[dtrain, dval], 
                             verbose_eval=100, early_stopping_rounds=50,
                             learning_rates = lambda iter: 0.05 * (0.99 ** iter))
        
        y_pred_rg = model_rg.predict(X_test, num_iteration=model_rg.best_iteration)
        
        # add model predictions for this drug to a dataframe
        scores.loc[ids[test], drug] = y_pred_rg
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.498313	valid_1's l2: 2.43838
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.498313	valid_1's l2: 2.43838
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.512505	valid_1's l2: 2.48754
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.512505	valid_1's l2: 2.48754
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.465256	valid_1's l2: 2.26306
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.465256	valid_1's l2: 2.26306
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.481849	valid_1's l2: 2.5939
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.481849	valid_1's l2: 2.5939
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.513875	valid_1's l2: 2.20708
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.513875	valid_1's l2: 2.20708
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.164173	valid_1's l2: 0.464757
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.164173	valid_1's l2: 0.464757
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's l2: 0.303571	valid_1's l2: 0.48105
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's l2: 0.260914	valid_1's l2: 0.65085
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's l2: 0.495495	valid_1's l2: 0.770667
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.155568	valid_1's l2: 0.520233
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.155568	valid_1's l2: 0.520233
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 0.598171	valid_1's l2: 0.688294
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's l2: 0.669694	valid_1's l2: 0.800458
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's l2: 0.702498	valid_1's l2: 0.868947
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.264271	valid_1's l2: 0.62434
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.264271	valid_1's l2: 0.62434
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's l2: 0.446211	valid_1's l2: 0.713801
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 0.457579	valid_1's l2: 0.787195
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 0.424091	valid_1's l2: 0.727186
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.172663	valid_1's l2: 0.867006
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.172663	valid_1's l2: 0.867006
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 0.61547	valid_1's l2: 1.01088
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's l2: 0.67091	valid_1's l2: 0.831043
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.56144	valid_1's l2: 2.90526
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.56144	valid_1's l2: 2.90526
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's l2: 1.502	valid_1's l2: 3.21778
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's l2: 2.043	valid_1's l2: 3.11693
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's l2: 1.07865	valid_1's l2: 2.93842
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's l2: 1.36284	valid_1's l2: 3.07795
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 0.99097	valid_1's l2: 1.64198
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's l2: 0.6767	valid_1's l2: 1.17197
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.43195	valid_1's l2: 1.78591
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.43195	valid_1's l2: 1.78591
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.389672	valid_1's l2: 1.46759
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.389672	valid_1's l2: 1.46759
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.418302	valid_1's l2: 1.17522
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.418302	valid_1's l2: 1.17522
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's l2: 0.254168	valid_1's l2: 0.600375
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.132214	valid_1's l2: 0.598567
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.132214	valid_1's l2: 0.598567
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.12988	valid_1's l2: 0.68572
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.12988	valid_1's l2: 0.68572
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's l2: 0.356892	valid_1's l2: 0.546197
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.12631	valid_1's l2: 0.624229
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.12631	valid_1's l2: 0.624229
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.302459	valid_1's l2: 1.19514
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.337464	valid_1's l2: 0.999879
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.337464	valid_1's l2: 0.999879
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's l2: 0.454861	valid_1's l2: 0.692736
# Training until validation scores don't improve for 50 rounds
# [100]	training's l2: 0.361758	valid_1's l2: 1.38509
# Did not meet early stopping. Best iteration is:
# [100]	training's l2: 0.361758	valid_1's l2: 1.38509
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's l2: 0.718266	valid_1's l2: 0.946028
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's l2: 1.00022	valid_1's l2: 2.10975
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's l2: 0.859784	valid_1's l2: 1.392
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's l2: 1.17762	valid_1's l2: 1.88962
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's l2: 1.46245	valid_1's l2: 1.71713
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's l2: 1.36618	valid_1's l2: 2.27227

# %% [markdown]
# #### Ranking drugs for given cell lines
#
# The top 10 drugs of the sorted array `pred` are the 10 most sentitive drugs for this given cell line based on model prediction. If we had a single train/val/test split rather than having to do cross-validation, we would have a single model and would be able to make predictions using the model for any cell line of interest that a user may input. But for this question I aggregated predictions for all cell lines in a dataframe for further analysis.
#
# The ranked lists of drugs for each cell line were compared using both Kendall's Tau and Spearman’s rank correlation coefficients. These two correlation coefficients both assess statistical associations based on the ranks of the data, but Kendall's Tau is based on concordant and discordant pairs, whereas Spearman is based on deviations.
#
# We can see from the results that the correlation between the model prediction and the experimental results varied quite a bit for different cell lines, some matching fairly well and the other not so much. The two metrics, Kendall's Tau and Spearman, were in agreement.

# %%
from scipy.stats import spearmanr, kendalltau

# dataframe for correlation scores between model prediction and experimental results
corr = pd.DataFrame(columns = ['Kendall_Tau','Kendall_Tau_top10drugs','Spearman','Spearman_top10drugs'], index = scores.index) 

for cell_line in scores.index:
    # sorting prediction and experimental scores for each given cell line
    pred = scores.loc[cell_line].sort_values()
    expt = exprmt.loc[cell_line].sort_values()
    
    # calculate Kendall Tau and Spearman correlations of all drugs from model prediction and experimental results
    corr.loc[cell_line, 'Kendall_Tau'] = kendalltau(pred.index.astype('str'),expt.index.astype('str'))[0]
    corr.loc[cell_line, 'Spearman'] = spearmanr(pred.index.astype('str'),expt.index.astype('str'))[0]
    # calculate Kendall Tau and Spearman correlations of just 10 top-ranking drugs from model prediction and experimental results
    corr.loc[cell_line, 'Kendall_Tau_top10drugs'] = kendalltau(pred.index[0:10].astype('str'),expt.index[0:10].astype('str'))[0]
    corr.loc[cell_line, 'Spearman_top10drugs'] = spearmanr(pred.index[0:10].astype('str'),expt.index[0:10].astype('str'))[0]

display(corr.head(10))
# Out:
#              Kendall_Tau Kendall_Tau_top10drugs   Spearman Spearman_top10drugs
# GENE_SYMBOLS
# 906826          0.285992               0.422222     0.3976            0.539394
# 687983        -0.0385363               0.155556 -0.0553264            0.139394
# 910927          0.301887                    0.2    0.41828            0.284848
# 1240138          0.24048               0.333333   0.334221            0.466667
# 1240139         0.408862              0.0222222   0.537224          -0.0424242
# 906792          0.396341               0.155556   0.505349            0.272727
# 910688          0.035506               0.422222  0.0512265            0.612121
# 1240135         0.614237               0.422222   0.761314                 0.6
# 1290812         0.359005              -0.466667   0.474743           -0.539394
# 907045          0.217896               0.155556   0.310617            0.224242
